# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_excel("Group_3.xlsx")

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
df.shape
# Out:
# (30000, 25)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
pd.set_option('display.max_rows', None)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default.payment.next.month    0
# dtype: int64

# %%
df.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['EDUCATION'].value_counts().sort_index()
# Out:
# EDUCATION
# 0       14
# 1    10585
# 2    14030
# 3     4917
# 4      123
# 5      280
# 6       51
# Name: count, dtype: int64

# %%
df['MARRIAGE'].value_counts().sort_index()
# Out:
# MARRIAGE
# 0       54
# 1    13659
# 2    15964
# 3      323
# Name: count, dtype: int64

# %%
sorted(df['PAY_0'].unique())
# Out:
# [np.int64(-2),
#  np.int64(-1),
#  np.int64(0),
#  np.int64(1),
#  np.int64(2),
#  np.int64(3),
#  np.int64(4),
#  np.int64(5),
#  np.int64(6),
#  np.int64(7),
#  np.int64(8)]

# %%
for pay_column in ['PAY_0','PAY_2','PAY_3','PAY_4','PAY_5','PAY_6']:
    print(f"{pay_column} : {sorted(df[pay_column].unique())}")
# Out:
# PAY_0 : [np.int64(-2), np.int64(-1), np.int64(0), np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6), np.int64(7), np.int64(8)]
# PAY_2 : [np.int64(-2), np.int64(-1), np.int64(0), np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6), np.int64(7), np.int64(8)]
# PAY_3 : [np.int64(-2), np.int64(-1), np.int64(0), np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6), np.int64(7), np.int64(8)]
# PAY_4 : [np.int64(-2), np.int64(-1), np.int64(0), np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6), np.int64(7), np.int64(8)]
# PAY_5 : [np.int64(-2), np.int64(-1), np.int64(0), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6), np.int64(7), np.int64(8)]
# PAY_6 : [np.int64(-2), np.int64(-1), np.int64(0), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6), np.int64(7), np.int64(8)]

# %%
# Moving other values in education that are not documented to 4 - Others

df.loc[df["EDUCATION"].isin([0,5,6]), "EDUCATION"] = 4

# %%
df.loc[df["MARRIAGE"].isin([0]), "MARRIAGE"] = 3

# %%
print(df["EDUCATION"].value_counts().sort_index())
# Out:
# EDUCATION
# 1    10585
# 2    14030
# 3     4917
# 4      468
# Name: count, dtype: int64

# %%
print(df["MARRIAGE"].value_counts().sort_index())
# Out:
# MARRIAGE
# 1    13659
# 2    15964
# 3      377
# Name: count, dtype: int64

# %%
df['default.payment.next.month'].value_counts()
# Out:
# default.payment.next.month
# 0    23364
# 1     6636
# Name: count, dtype: int64

# %%
df['default.payment.next.month'].value_counts(normalize=True) * 100
# Out:
# default.payment.next.month
# 0    77.88
# 1    22.12
# Name: proportion, dtype: float64

# %%
sns.countplot(x = 'default.payment.next.month', data = df)
plt.title("Class Imbalance - Default VS No Default")
plt.xlabel('Default (1 = Yes, 0 = No)')
plt.ylabel('Count')
plt.show()

# %%
df.hist(figsize=(20,15), bins=30, edgecolor= 'black')
plt.suptitle('Distribution of All Features', y=1.02)
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 10))

cols = ['LIMIT_BAL', 'AGE', 'BILL_AMT1', 'BILL_AMT2', 'PAY_AMT1', 'PAY_AMT2']

for i, col in enumerate(cols):
    row = i // 3
    col_idx = i % 3
    axes[row, col_idx].boxplot(df[col])
    axes[row, col_idx].set_title(col)

plt.suptitle('Outlier Detection — Box Plots')
plt.tight_layout()
plt.show()

# %%
numerical_cols = ['LIMIT_BAL', 'AGE', 'BILL_AMT1', 'BILL_AMT2', 
                  'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6',
                  'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 
                  'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']


for col in numerical_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = df[(df[col] < lower) | (df[col] > upper)]
    pct = len(outliers) / len(df) * 100
    print(f"{col}: {len(outliers)} outliers ({pct:.1f}%)")
# Out:
# LIMIT_BAL: 167 outliers (0.6%)
# AGE: 272 outliers (0.9%)
# BILL_AMT1: 2400 outliers (8.0%)
# BILL_AMT2: 2395 outliers (8.0%)
# BILL_AMT3: 2469 outliers (8.2%)
# BILL_AMT4: 2622 outliers (8.7%)
# BILL_AMT5: 2725 outliers (9.1%)
# BILL_AMT6: 2693 outliers (9.0%)
# PAY_AMT1: 2745 outliers (9.2%)
# PAY_AMT2: 2714 outliers (9.0%)
# PAY_AMT3: 2598 outliers (8.7%)
# PAY_AMT4: 2994 outliers (10.0%)
# PAY_AMT5: 2945 outliers (9.8%)
# PAY_AMT6: 2958 outliers (9.9%)

# %%
# Correlation Heatmap

plt.figure(figsize=(20,16))

sns.heatmap(df.corr(),
            annot=True,
            fmt='.2f',
            cmap='coolwarm',
            center=0,
            linewidths=0.5)

plt.title('Correlation Heatmap — All Features', fontsize=16)
plt.tight_layout()
plt.show()

# %%
corr_with_target = df.corr()['default.payment.next.month'].sort_values(ascending=False)
print(corr_with_target)
# Out:
# default.payment.next.month    1.000000
# PAY_0                         0.324794
# PAY_2                         0.263551
# PAY_3                         0.235253
# PAY_4                         0.216614
# PAY_5                         0.204149
# PAY_6                         0.186866
# EDUCATION                     0.033842
# AGE                           0.013890
# BILL_AMT6                    -0.005372
# BILL_AMT5                    -0.006760
# BILL_AMT4                    -0.010156
# ID                           -0.013952
# BILL_AMT3                    -0.014076
# BILL_AMT2                    -0.014193
# BILL_AMT1                    -0.019644
# MARRIAGE                     -0.027575
# SEX                          -0.039961
# PAY_AMT6                     -0.053183
# PAY_AMT5                     -0.055124
# PAY_AMT3                     -0.056250
# PAY_AMT4                     -0.056827
# PAY_AMT2                     -0.058579
# PAY_AMT1                     -0.072929
# ...

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

for i, col in enumerate(['EDUCATION', 'MARRIAGE', 'SEX']):
    default_rate = df.groupby(col)['default.payment.next.month'].mean() * 100
    axes[i].bar(default_rate.index, default_rate.values, color='steelblue', edgecolor='black')
    axes[i].set_title(f'Default Rate by {col}')
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Default Rate (%)')

plt.suptitle('Default Rate by Demographic Group', fontsize=14)
plt.tight_layout()
plt.show()

# %%
print("=" * 50)
print("SECTION 1 — DATA QUALITY SUMMARY")
print("=" * 50)

print(f"\nDataset Shape: {df.shape}")
print(f"Missing Values: {df.isnull().sum().sum()}")
print(f"Duplicate Rows: {df.duplicated().sum()}")

print(f"\nClass Balance:")
print(df['default.payment.next.month'].value_counts(normalize=True).mul(100).round(2))

print(f"\nUndocumented Values Fixed:")
print(f"EDUCATION 0,5,6 → recoded to 4 (Other)")
print(f"MARRIAGE 0 → recoded to 3 (Other)")
print(f"PAY columns contain -2 → retained as no consumption")

print(f"\nOutliers (IQR method):")
numerical_cols = ['LIMIT_BAL', 'AGE', 'BILL_AMT1', 'BILL_AMT2',
                  'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6',
                  'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3',
                  'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']
for col in numerical_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    outliers = df[(df[col] < Q1 - 1.5*IQR) | (df[col] > Q3 + 1.5*IQR)]
    print(f"  {col}: {len(outliers)} outliers ({len(outliers)/len(df)*100:.1f}%)")

print(f"\nTop Correlations with Default:")
corr = df.corr()['default.payment.next.month'].sort_values(ascending=False)
print(corr.head(6))
print("...")
print(corr.tail(3))
# Out:
# ...
# SECTION 1 — DATA QUALITY SUMMARY
# ...
#
# Dataset Shape: (30000, 25)
# Missing Values: 0
# Duplicate Rows: 0
#
# Class Balance:
# default.payment.next.month
# 0    77.88
# 1    22.12
# Name: proportion, dtype: float64
#
# Undocumented Values Fixed:
# EDUCATION 0,5,6 → recoded to 4 (Other)
# MARRIAGE 0 → recoded to 3 (Other)
# PAY columns contain -2 → retained as no consumption
#
# Outliers (IQR method):
#   LIMIT_BAL: 167 outliers (0.6%)
#   AGE: 272 outliers (0.9%)
#   BILL_AMT1: 2400 outliers (8.0%)
#   BILL_AMT2: 2395 outliers (8.0%)
#   BILL_AMT3: 2469 outliers (8.2%)
#   BILL_AMT4: 2622 outliers (8.7%)
#   BILL_AMT5: 2725 outliers (9.1%)
#   BILL_AMT6: 2693 outliers (9.0%)
#   PAY_AMT1: 2745 outliers (9.2%)
#   PAY_AMT2: 2714 outliers (9.0%)
#   PAY_AMT3: 2598 outliers (8.7%)
#   PAY_AMT4: 2994 outliers (10.0%)
#   PAY_AMT5: 2945 outliers (9.8%)
#   PAY_AMT6: 2958 outliers (9.9%)
#
# Top Correlations with Default:
# default.payment.next.month    1.000000
# ...

# %% [markdown]
# Section 2 and 3 are done in the second file
